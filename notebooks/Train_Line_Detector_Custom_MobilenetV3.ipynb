# %%
#@title Clone repo
# !git clone https://github.com/toannn20/SceneStructNet
# Out:
# Cloning into 'SceneStructNet'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 94 (delta 29), reused 79 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 30.08 MiB | 20.60 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !unzip /content/drive/MyDrive/Datasets/google_image_line.zip -d /content/dataset
# Out:
# Archive:  /content/drive/MyDrive/Datasets/google_image_line.zip
#    creating: /content/dataset/images/
#    creating: /content/dataset/images/architecture_photography/
#   inflating: /content/dataset/images/architecture_photography/5acfe38395b51ecf90dbc04d0eefb03c67cb8511.jpg
#   inflating: /content/dataset/images/architecture_photography/87bb514827fa5979cae4536d1ad4e254707fe217.jpg
#   inflating: /content/dataset/images/architecture_photography/a23a5dfa4395f56e4a45a4c2d04d0b0caa598c26.jpg
#   inflating: /content/dataset/images/architecture_photography/4039d43087c399ead0b506e218d7c8cf94d75794.jpg
#   inflating: /content/dataset/images/architecture_photography/de67258523c69bbb268ca5a26d36b76903bd2014.jpg
#   inflating: /content/dataset/images/architecture_photography/82359de823485900173f589fb4e8ac77bf5b5f99.jpg
#   inflating: /content/dataset/images/architecture_photography/d409f0e9d4526e646ca5928c3358d0b6dc425cb1.jpg
# ...

# %%
# %cd SceneStructNet
# Out:
# /content/SceneStructNet

# %%
# !python line_detector/train.py --data_dir /content/dataset/ --images_dir /content/dataset/images/ --epochs 10 --batch_size 8
# Out:
# Device: cuda | Train: 331 | Val: 85
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100% 21.1M/21.1M [00:00<00:00, 169MB/s]
#
# Epoch 1/10
#   Train: 100% 41/41 [00:37<00:00,  1.09it/s, L=243740]
#   Val  : 100% 11/11 [00:07<00:00,  1.52it/s]
#   sAP  : 100% 11/11 [00:14<00:00,  1.31s/it]
#     heatmap_max: start=0.859 end=0.998 | peaks: 15288+14428 | lines: 25500 | gt: 1472 (85 imgs)
#
#   ────────────────────────────────────────────────────
#   Epoch 1 Summary
#   ────────────────────────────────────────────────────
#                       Train          Val
#   loss            243739.79    166198.54
#   cls_loss        132165.62     99860.73
#   seg_loss        111574.17     66337.80
#   start_loss        9727.82      9137.20
#   end_loss         23313.59     15827.98
#   line_loss        22314.83     13267.56
#   ────────────────────────────────────────────────────
# ...

# %%
# !python line_detector/evaluate.py --checkpoint checkpoints/best.pth --data_dir /content/dataset/ --images_dir /content/dataset/images/ --split val --visualize --vis_dir eval_vis --num_vis 10
# Out:
# Loaded checkpoint — epoch 10
# Evaluating 85 images (val set)
#
#   sAP  : 100% 11/11 [00:06<00:00,  1.74it/s]
#     heatmap_max: start=0.707 end=0.611 | peaks: 13+108 | lines: 56 | gt: 1472 (85 imgs)
# ...
#   sAP5 = 0.00
#   sAP10 = 0.00
#   sAP15 = 0.00
# ...
# Saved metrics → checkpoints/eval_val.json
# Saved 10 visualizations to eval_vis/
