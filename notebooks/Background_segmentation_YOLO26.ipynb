# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !cp /content/drive/MyDrive/Datasets/raw_images/*.zip /content/

# %%
import zipfile
import os

data_dir = "/content/data/images"
zip_dir = "/content/"
os.makedirs(data_dir, exist_ok=True)

for filename in os.listdir(zip_dir):
    if filename.endswith(".zip"):
        folder_name = os.path.splitext(filename)[0]
        folder_path = os.path.join(data_dir, folder_name)
        os.makedirs(folder_path, exist_ok=True)
        with zipfile.ZipFile(os.path.join(zip_dir, filename), 'r') as zip_ref:
            zip_ref.extractall(folder_path)
        print(f"Extracted: {filename} → {folder_path}")

for filename in os.listdir(zip_dir):
    if filename.endswith(".zip"):
        os.remove(os.path.join(zip_dir, filename))
        print(f"Deleted: {filename}")
# Out:
# Extracted: train.zip → /content/data/images/train
# Extracted: test.zip → /content/data/images/test
# Extracted: valid.zip → /content/data/images/valid
# Deleted: train.zip
# Deleted: test.zip
# Deleted: valid.zip

# %%
# !cp /content/drive/MyDrive/Datasets/background_seg/*.zip /content/

# %%
import zipfile
import os

data_dir = "/content/data/labels"
zip_dir = "/content/"
os.makedirs(data_dir, exist_ok=True)

for filename in os.listdir(zip_dir):
    if filename.endswith(".zip"):
        folder_name = os.path.splitext(filename)[0]
        folder_path = os.path.join(data_dir, folder_name)
        os.makedirs(folder_path, exist_ok=True)
        with zipfile.ZipFile(os.path.join(zip_dir, filename), 'r') as zip_ref:
            zip_ref.extractall(folder_path)
        print(f"Extracted: {filename} → {folder_path}")

for filename in os.listdir(zip_dir):
    if filename.endswith(".zip"):
        os.remove(os.path.join(zip_dir, filename))
        print(f"Deleted: {filename}")
# Out:
# Extracted: train.zip → /content/data/labels/train
# Extracted: test.zip → /content/data/labels/test
# Extracted: val.zip → /content/data/labels/val
# Deleted: train.zip
# Deleted: test.zip
# Deleted: val.zip

# %%
# Load YOLO26n-seg
from ultralytics import YOLO

model = YOLO('yolo26n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='/content/drive/MyDrive/Datasets/background_seg/custom_data.yaml', epochs=3)  # train the model
model('/content/data/images/test/gg_architecture_094ffe9a22fb863211de7386157fd9da6558a86e.jpg')  # predict on an image
# Out:
# ...
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
